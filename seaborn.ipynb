# %%
import pandas as pd
#pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
#%matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
fifa_filepath= 'fifa.csv'

df= pd.read_csv(fifa_filepath, index_col='Date', parse_dates=True)

df.head()

plt.figure(figsize=(16, 6)) #size of window
plt.title('Fifa rankings')
sns.lineplot(data=df) #seaborn plots 
list(df.columns)
df
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
plt.figure(figsize=(14,6))
plt.title('Brazil fifa rankings')

sns.lineplot(data=df['BRA'], label='Brazil')
sns.lineplot(data=df['ARG'], label='Argentina')
#sns.barplot(x=df.index, y=df.BRA)
#sns.heatmap(data=df, annot=True)
# Out:
# <Axes: title={'center': 'Brazil fifa rankings'}, xlabel='Date', ylabel='BRA'>

# %%
df1=pd.read_csv('wine.csv')
plt.figure(figsize=(16,8))
# sns.scatterplot(x= df1['points'], y=df1['price'])
# sns.regplot(x= df1['points'], y=df1['price'])
#sns.scatterplot(x= df1['points'], y=df1['price'], hue=df1['taster_twitter_handle'])
sns.lmplot(x= 'points', y='price', hue='taster_twitter_handle', data=df1)
#

# %%
c_data=pd.read_csv('cancer.csv', index_col='Id')



plt.figure(figsize=(16,8))

sns.set_style('darkgrid')

#sns.histplot(x=c_data['Radius (mean)'])
#sns.histplot(data=c_data, x="Area (mean)", hue='Diagnosis')
sns.kdeplot(data=c_data, x='Radius (worst)', hue='Diagnosis', shade=True)
#sns.jointplot(x= c_data['Radius (mean)'], y= c_data['Radius (mean)'], kind="kde")

c_data.head()
# Out:
# C:\Users\David Danell\AppData\Local\Temp\ipykernel_25372\4202465268.py:11: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data=c_data, x='Radius (worst)', hue='Diagnosis', shade=True)
#          Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# Id
# 8510426          B         13.540           14.36             87.46
# 8510653          B         13.080           15.71             85.63
# 8510824          B          9.504           12.44             60.34
# 854941           B         13.030           18.42             82.61
# 85713702         B          8.196           16.84             51.71
#
#           Area (mean)  Smoothness (mean)  Compactness (mean)  \
# Id
# 8510426         566.3            0.09779             0.08129
# 8510653         520.0            0.10750             0.12700
# ...
